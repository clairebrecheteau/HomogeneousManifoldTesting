# %% [markdown]
# # Generating samples on the circle, the sphere, the torus, the Grassmannian and the Bolza Surface

# %%
using HomogeneousManifoldTesting
using LinearAlgebra: Diagonal

# %% [markdown]
# ## 1) Circle

# %%
a = CircleData(500,"uniform")
plot_data(a)

# %%
κ = 2
center_ = [sqrt(2)/2,sqrt(2)/2]
a = CircleData(500,"FvM",κ,center_)
#plot_data(a)
# Out:
# ┌ Warning: RCall.jl: Le chargement a nécessité le package : Rcpp
# └ @ RCall /home/claire/.julia/packages/RCall/0ggIQ/src/io.jl:172
# CircleData{Float64}(500, [6.163610282077734, 1.4261679168496169, 6.0761205698955285, 1.791268402917942, 0.812880676502722, 0.36951246937869775, 1.19417850087102, 0.5329752356972653, 1.5835308036964482, 5.82378580255696  …  6.006214430362472, 0.887240738928426, 1.9947370086475782, 0.3149428123243943, 1.0602411618365706, 1.5084333694057064, 0.08090990876518346, 0.664954881787819, 0.3490742807658247, 0.07498640699005761])

# %%
κ = 10
a = CircleData(500,"MFvM",κ)
#plot_data(a)
# Out:
# CircleData{Float64}(500, [3.013899649746415, 2.772322756364715, 5.347858302617092, 3.767267306486612, 4.383777891593368, 1.6600017670433895, 4.591232281944185, 2.76905632169546, 0.08318427751583975, 0.23933521454351747  …  2.6957972871259206, 2.807061699880994, 4.290511746586001, 4.424630811115854, 3.8603964109002695, 2.8884624456209353, 2.9361031095771777, 1.527460413587659, 4.90466137372189, 1.082625988923337])

# %%
a = CircleData(100,"normal",6,0.3)
#plot_data(a)
# Out:
# CircleData{Float64}(100, [6.033888724964711, 6.210401131340002, 6.190366521897338, 5.991978997443701, 6.173386840969048, 5.343944216574677, 5.965193560642452, 6.008989144267673, 6.107097387791703, 0.08622815550112328  …  0.11577587379867449, 5.735128793380139, 0.05020824980003358, 6.083604350266933, 6.075924277092035, 5.678153490407195, 0.004089385866311801, 6.064050656978159, 5.839204553962519, 5.933777487285731])

# %%
a = CircleData(100,"mixture normal",[0,1],[0.1,0.2],[0.3,0.7])
#plot_data(a)
# Out:
# CircleData{Float64}(100, [0.15364782432147808, 6.16217676803575, 0.21540864245617214, 6.236203053312557, 0.07501782697190859, 0.08555254100337674, 6.22112421707551, 0.2234874880624608, 6.155598445252868, 6.245267006268436  …  1.2877634820537665, 1.2616500752840458, 0.70442683137815, 1.125951931466647, 0.873701568662199, 1.190823068973006, 0.9554511001973934, 1.0029206793434924, 1.080170877638277, 1.1032945200579052])

# %%
a = CircleData(100,"dynamical system",0.2,4)
#plot_data(a)
# Out:
# CircleData{Float64}(100, [0.8, 1.0, 1.2000000000000002, 1.4000000000000001, 1.6, 1.8, 2.0, 2.2, 2.4000000000000004, 2.6  …  6.233629385640828, 0.1504440784612413, 0.35044407846124415, 0.5504440784612434, 0.7504440784612427, 0.950444078461242, 1.1504440784612413, 1.3504440784612441, 1.5504440784612434, 1.7504440784612427])

# %%
a = CircleData(100,"dynamical system 2",1000)
#plot_data(a)
# Out:
# CircleData{Float64}(100, [0.5519685080490433, 0.7905518332789825, 1.0291351585089217, 1.2677184837388609, 2.3388083946340217, 1.7448851341987393, 2.8159750450939, 2.2220517846586176, 3.2931416955537784, 2.699218435118496  …  3.4730074059661504, 6.2091104881917545, 1.9082935069533988, 4.644396589179003, 1.0973143642250207, 3.8334174464506248, 0.2863352214966426, 2.268703547437873, 5.004806629663477, 1.457724404709495])

# %% [markdown]
# ## 2) Sphere

# %%
a = SphereData(500,"uniform")
plot_data(a)

# %%
κ = 2
center_ = [0,sqrt(2)/2,sqrt(2)/2]
a = SphereData(500,"FvM",κ,center_)
#plot_data(a,0.25)
# Out:
# SphereData{Float64}(500, [0.4444447166700534 0.09980369323295896 … 0.08963071448003383 -0.17410414867686574; 0.785469546969419 0.8632986843407953 … 0.9230340538356001 0.291515207808082; -0.43070463731858266 0.4947267977707632 … 0.37413162186805005 0.9405884482759261])

# %%
κ = 10
a = SphereData(500,"MFvM",κ)
#plot_data(a)
# Out:
# SphereData{Float64}(500, [-0.11715028406316197 0.3748830997544149 … -0.5635278274546247 -0.9275412456623824; -0.022930321823446776 0.26401309817737456 … 0.8168982345282093 0.36421931206756614; 0.9928494403911369 -0.8886842777439609 … 0.12293763503893106 -0.0837348810956635])

# %% [markdown]
# ## 3) Torus

# %%
a = TorusData(500,"uniform")
plot_data(a)

# %%
μ = [0,0.5]
Σ = Matrix(Diagonal([0.3,0.03]))
a = TorusData(1000,"normal",μ,Σ)
#plot_data(a)
# Out:
# TorusData{Float64}(1000, [0.9723285157004429 0.03439250779844216 … 0.3693318751284145 0.9496513990447748; 0.706404272747807 0.5287976654631887 … 0.4851548017806473 0.6074818623227287])

# %%
vect_μ = [[0,0.5],[0.5,0.3]]
vect_Σ = [Matrix(Diagonal([0.2^2,0.3^2])),Matrix(Diagonal([0.5^2,0.1^2]))]
proba = [0.3,0.7]
a = TorusData(1000,"mixture normal",vect_μ,vect_Σ,proba)
#plot_data(a)
# Out:
# TorusData{Float64}(1000, [0.912732993314709 0.6670913555247009 … 0.9736974579360752 0.34355164864624665; 0.7284997825278148 0.9810343919540396 … 0.24734350036603736 0.2463264724193639])

# %%
a = TorusData(100,"large circle incremental",200,[0.5,0.5])
#plot_data(a)
# Out:
# TorusData{Float64}(100, [0.7973996547942477 0.17481778423265837 … 0.7511994375808655 0.13464913917007948; 0.7703759866879736 0.5628257555535754 … 0.2692816542544847 0.6542023600394771])

# %%
a = TorusData(100,"large circle uniform",200,[0.5,0.5])
#plot_data(a)
# Out:
# TorusData{Float64}(100, [0.028209695191520723 0.4047213136509953 … 0.760728690712142 0.8446634570126292; 0.9536061791400243 0.548555439623641 … 0.9165985156844556 0.9065095744693679])

# %%
a = TorusData(100,"large circle equidistant",200,[0.5,0.5])
#plot_data(a)
# Out:
# TorusData{Float64}(100, [0.10534568565429936 0.9229402628955654 … 0.10534568565429936 0.5; 0.058103905862674665 0.5666467128608517 … 0.9418960941373467 0.49999999999995104])

# %%
p0 = [0.5,0.5]
r1 = 0.4
r2 = 1
angle = 0.4
a = TorusData(100,"large ellipse incremental",p0,r1,r2,angle)
#plot_data(a)
# Out:
# TorusData{Float64}(100, [0.9012036763369775 0.15769276494065046 … 0.9180449253524302 0.17819309790197507; 0.5844970182720222 0.2846361499049765 … 0.5946263811812039 0.24061978346624996])

# %%
p0 = [0.5,0.5]
r1 = 0.4
r2 = 1
angle = 0.4
a = TorusData(100,"large ellipse uniform",p0,r1,r2,angle)
#plot_data(a)
# Out:
# TorusData{Float64}(100, [0.16521002284303588 0.6707748347724677 … 0.9637219833134065 0.02747244788087122; 0.4337482656891085 0.028243835000141937 … 0.6394667890922997 0.8138195049285312])

# %%
p0 = [0.5,0.5]
r = 0.4
angle = 2.4
angle1 = 4.5
a = TorusData(100,"large circle line incremental",p0,r,angle,angle1)
#plot_data(a)
# Out:
# TorusData{Float64}(100, [0.44052716510934214 0.4432423327819185 … 0.2350150069411186 0.2211084501157673; 0.5599047087148438 0.5628688193222715 … 0.20036196260557204 0.213260565315528])

# %%
p0 = [0.5,0.5]
r = 0.4
angle = 2.4
angle1 = 4.5
a = TorusData(100,"large circle line uniform",p0,r,angle,angle1)
#plot_data(a)
# Out:
# TorusData{Float64}(100, [0.46965019845079997 0.4564811344613514 … 0.4905811771487454 0.4901043106050007; 0.5916979172594847 0.577321434121712 … 0.10011090815565288 0.10012242457047221])

# %%
alp = 0.241
bet = 0.834
a = TorusData(1000,"dynamical system",alp,bet)
#plot_data(a)
# Out:
# TorusData{Float64}(1000, [0.0 0.241 … 0.5180000000000007 0.7589999999999861; 0.0 0.834 … 0.33199999999999363 0.16599999999993997])

# %%
p0 = [0.5,0.5]
a = TorusData(1000,"dynamical system2",p0)
#plot_data(a)
# Out:
# TorusData{Float64}(1000, [0.5 0.5 … 0.0 0.5; 0.5 0.0 … 0.5 0.5])

# %%
p0 = [0.5,0.5]
a = TorusData(1000,"dynamical system3",p0)
#plot_data(a)
# Out:
# TorusData{Float64}(1000, [0.5 0.25 … 0.0 0.0; 0.5 0.25 … 0.0 0.0])

# %% [markdown]
# ## 4) Grassmann (2,3)

# %%
a = GrassmannData23(100,"uniform")
plot_data(a)

# %%
a = GrassmannData23(100,"mixture_normal",0.1)
#plot_data(a)
# Out:
# GrassmannData23{Matrix{Float64}}(100, [[-0.1274083594476314 0.08197176846084986; -0.9918364400137589 -0.005252257009741079; -0.005252257009740921 -0.9966208120301845], [-0.08869024609821108 0.09180384588082313; -0.9960508673564786 -0.004087772675332335; -0.004087772675332224 -0.9957687201333675], [-0.999451424750899 0.0021480655929555234; 0.002148065592955547 -0.9915887823973075; 0.033048984517022234 0.1294104804026057], [-0.05384862051966177 0.1450555368869949; -0.9985413800215713 -0.003929179652945924; 0.003929179652945761 0.9894157128152354], [-0.9992592307762915 0.0003689393022916073; 0.00036893930229159224 -0.9998162501837025; -0.03848186056008403 -0.019165848595653606], [-0.9998932983333986 4.819918488293065e-5; -0.014607861746193 -0.006598650719099597; 4.8199184882924214e-5 -0.9999782275057421], [-0.08244560866620576 -0.04592611721453277; 0.9965937594335778 -0.001897437668848756; 0.0018974376688485793 -0.998943037158721], [-0.9958641864441267 0.0008409212413838241; -0.0908505091314505 -0.018472332441261674; -0.0008409212413838181 0.9998290182754476], [-0.0915466207743969 -0.011078826875933867; 0.9958006617593398 -0.00050819725477802; -0.0005081972547781321 0.9999384987741013], [-0.051198668890593435 -0.033895660486054635; 0.9986881104563347 -0.0008685257552751846; -0.0008685257552752347 0.999424999618894]  …  [-0.041319436703798784 -0.026317351302699965; 0.9991458392925785 -0.0005440356693948711; 0.0005440356693949341 -0.9996534
 -0.03141102560639223; 0.03141102560639248 -0.8451950248034189], [-0.9623398391512228 0.05787654677715466; -0.06695227817407176 -0.7515044105772333; 0.057876546777154675 -0.6363360321147201; 0.2570403310044016 0.16421900148463567], [-0.9968334546109445 -0.0034421153164415053; -0.0034421153164415044 -0.9962570310219774; 0.04244619959337908 -0.044775942354559076; 0.06715307700051776 -0.07385929168144335], [-0.9998183475379767 -0.0001582010284789069; -0.00015820102847892962 -0.9998604797174699; -0.018850628168431905 0.016692351564319915; 0.0028108213247846595 -0.0006012244494839452], [-0.6642589497350895 -0.04258043757384122; 0.7455311972481076 -0.11015666190925844; -0.03361826828762678 -0.6416439411210734; 0.04258043757384119 0.7578558365518115], [-0.20297851003999234 -0.20519777433892727; 0.9768516785251344 -0.03293371628950714; -0.058956704079641216 -0.34954730699576136; 0.03293371628950733 -0.9135786358654212], [-0.9871418316302218 0.016258386106937958; -0.0655035965110614 -0.18920604538687202; -0.016258386106937976 0.972566429319348; 0.1448997859592768 0.13435504393685013], [-0.05384153620710652 -0.10013026092757264; 0.12191877065212621 -0.07825899499079769; 0.9910764462302056 0.002092861495528285; -0.0020928614955282006 -0.9918896513626742], [-0.045435407551446705 0.005386707143588555; 0.04180938405005715 -0.06651904836474842; 0.9980908278668965 0.0015160718854607981; 0.0015160718854608042 0.9977694629105643], [-0.0604813437821885 -0.06781610135361293; 0.9879608140469947 -0.0020230553079654268; -0.0020230553079653565 0.9976956105325522; -0.14237747086221753 0.00059360634714597]])

# %% [markdown]
# ## 6) Bolza surface

# %%
a = BolzaData(500,"uniform")
plot_data(a)

# %%
a = BolzaData(10000,"geodesic",0.02)
#plot_data(a)
# Out:
# BolzaData{Float64}(10000, [0.0 0.0016180770466260866 … 0.3845189885818305 0.3845485626863744; 0.0 0.009867885304474952 … 0.07503426396971466 0.08349268240096416])

# %%
a = BolzaData(100,"large circle incremental",200/1000,1000)
#plot_data(a)
# Out:
# BolzaData{Float64}(100, [-0.31044441326812827 -0.2940417945663106 … -0.5018362861498546 -0.13084337188949619; 0.549079393090004 -0.018884071935242098 … -0.004404916357136696 0.056539049347644595])

# %%
a = BolzaData(100,"large circle uniform",200/1000,1000)
#plot_data(a)
# Out:
# BolzaData{Float64}(100, [0.010511974081887863 -0.14446614018851606 … 0.6755622470283037 -0.20600211411214073; -0.4670958085280033 0.6627202427922968 … -0.3324177819455771 0.02737146596679311])

# %%
a = BolzaData(100,"brownian",0+0.3*im,30,5000)
#plot_data(a)
# Out:
# BolzaData{Float64}(100, [-0.2973495655463838 0.10286166667209706 … -0.3126122938858652 0.6865301173524813; -0.7351788734487584 -0.4123178921405126 … 0.3364577231238602 -0.3265023852400406])

# %%
a = BolzaData(500,"mixture_brownian",[0+0.3*im, 0 - 0.4*im],[1,1],[10,10],[0.3,0.7])
#plot_data(a)
# Out:
# BolzaData{Float64}(500, [-0.4026353624547059 -0.12080992447531425 … -0.029777106211398296 -0.42053902990909375; 0.28000666111908784 0.49503669852628834 … -0.5511879424312024 -0.2974306067806545])

# %%
z0,T,nsteps = 0*im, 30, 5000
a,jumps = simulate_brownian_bolza(z0,T,nsteps)
plot_brownian_motion_Bolza(a,jumps,5000,0.2)
